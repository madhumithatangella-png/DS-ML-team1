# %% [markdown]
# # Week 4: Noise Sensitivity Analysis and Threshold Tuning
#
# ## Introduction
#
# The objective of Week 4 is to evaluate the robustness of the predictive maintenance model under real-world operating conditions. In industrial environments, sensor readings often contain measurement noise due to environmental changes, hardware limitations, and communication errors. Therefore, it is important to assess how well the trained model performs when exposed to noisy input data.
#
# This phase begins by loading the trained LightGBM model and the processed dataset prepared during the previous weeks. The dataset is divided into training and testing sets, which will be used in the next stages to evaluate the model under noisy conditions, perform threshold tuning, and analyze its robustness.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_recall_curve,
    PrecisionRecallDisplay
)

import joblib

# %%
model = joblib.load("predictive_maintenance_model.pkl")

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
df=pd.read_csv(r"C:\Users\tange\week2_processed_data.csv")

# %%
df.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     1                298.2                    308.7                    1408
# 1     2                298.1                    308.6                    1425
# 2     1                298.1                    308.6                    1558
# 3     1                298.1                    308.6                    1527
# 4     2                298.3                    308.7                    1667
#
#    Torque [Nm]  Tool wear [min]  Machine failure  Torque_RollingMean  \
# 0         40.0                9                0               43.60
# 1         41.9               11                0               43.42
# 2         42.4               14                0               42.64
# 3         40.2               16                0               40.80
# 4         28.6               18                0               38.62
#
#    Torque_RollingStd  Torque_RollingVar  ...  Temp_Ratio  RPM_per_Torque  \
# 0           4.223150             17.835  ...    1.035211       34.341463
# 1           4.284507             18.357  ...    1.035223       33.216783
# 2           3.972782             15.783  ...    1.035223       35.898618
# 3           1.270827              1.615  ...    1.035223       37.063107
# 4           5.697543             32.462  ...    1.034864       56.317568
#
#    Ambient_Temperature  Humidity  Factory_Load  Shift   Heat_Stress  \
# 0            31.986857        68      0.782904      0   9874.342636
# 1            29.446943        61      0.962677      2   9087.326547
# 2            32.590754        59      0.512720      0  10057.506731
# 3            36.092119        45      0.854098      2  11138.028055
# 4            29.063387        82      0.665164      1   8971.867413
#
#    Load_Torque  Humidity_Wear  Temp_Load
# 0    31.316173            612  25.042648
# 1    40.336185            671  28.347908
# 2    21.739347            826  16.709946
# 3    34.334738            720  30.826206
# 4    19.023686           1476  19.331914
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9996 entries, 0 to 9995
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Type                     9996 non-null   int64
#  1   Air temperature [K]      9996 non-null   float64
#  2   Process temperature [K]  9996 non-null   float64
#  3   Rotational speed [rpm]   9996 non-null   int64
#  4   Torque [Nm]              9996 non-null   float64
#  5   Tool wear [min]          9996 non-null   int64
#  6   Machine failure          9996 non-null   int64
#  7   Torque_RollingMean       9996 non-null   float64
#  8   Torque_RollingStd        9996 non-null   float64
#  9   Torque_RollingVar        9996 non-null   float64
#  10  AirTemp_RollingMean      9996 non-null   float64
#  11  AirTemp_RollingStd       9996 non-null   float64
#  12  AirTemp_RollingVar       9996 non-null   float64
#  13  ProcessTemp_RollingMean  9996 non-null   float64
#  14  ProcessTemp_RollingStd   9996 non-null   float64
#  15  ProcessTemp_RollingVar   9996 non-null   float64
#  16  RPM_RollingMean          9996 non-null   float64
#  17  RPM_RollingStd           9996 non-null   float64
#  18  RPM_RollingVar           9996 non-null   float64
#  19  ToolWear_RollingMean     9996 non-null   float64
#  20  ToolWear_RollingStd      9996 non-null   float64
#  21  ToolWear_RollingVar      9996 non-null   float64
#  22  Temp_Difference          9996 non-null   float64
#  23  Power_Index              9996 non-null   float64
#  24  Wear_Torque              9996 non-null   float64
#  25  Temp_Ratio               9996 non-null   float64
#  26  RPM_per_Torque           9996 non-null   float64
#  27  Ambient_Temperature      9996 non-null   float64
#  28  Humidity                 9996 non-null   int64
#  29  Factory_Load             9996 non-null   float64
#  30  Shift                    9996 non-null   int64
#  31  Heat_Stress              9996 non-null   float64
#  32  Load_Torque              9996 non-null   float64
#  33  Humidity_Wear            9996 non-null   int64
#  34  Temp_Load                9996 non-null   float64
# dtypes: float64(28), int64(7)
# memory usage: 2.7 MB

# %%
X = df.drop("Machine ailure", axis=1)

y = df["Machine failure"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 X = df.drop("Machine_Failure", axis=1)
#       3 y = df["Machine_Failure"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Machine_Failure'] not found in axis"
